# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('D:\loan_data_set.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender'].fillna(0,inplace=True)
df['Married'].fillna(0,inplace=True)
df['Dependents'].fillna(0,inplace=True)
df['Self_Employed'].fillna('N/A',inplace=True)
df['Credit_History'].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
df['LoanAmount'].fillna(146,inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Loan_Amount_Term'].mean()
# Out:
# 342.0

# %%
df['Loan_Amount_Term'].fillna(342,inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df1=pd.read_csv('D:\loan_data_set.csv')

# %%
df2=pd.merge(df,df1,on='Loan_ID')

# %%
df2.head()
# Out:
#     Loan_ID Gender_x Married_x Dependents_x   Education_x Self_Employed_x  \
# 0  LP001002     Male        No            0      Graduate              No
# 1  LP001003     Male       Yes            1      Graduate              No
# 2  LP001005     Male       Yes            0      Graduate             Yes
# 3  LP001006     Male       Yes            0  Not Graduate              No
# 4  LP001008     Male        No            0      Graduate              No
#
#    ApplicantIncome_x  CoapplicantIncome_x  LoanAmount_x  Loan_Amount_Term_x  \
# 0               5849                  0.0         146.0               360.0
# 1               4583               1508.0         128.0               360.0
# 2               3000                  0.0          66.0               360.0
# 3               2583               2358.0         120.0               360.0
# 4               6000                  0.0         141.0               360.0
#
# ...

# %%
df.transform(func=lambda x:x*10)
# Out:
#                                                Loan_ID  \
# 0    LP001002LP001002LP001002LP001002LP001002LP0010...
# 1    LP001003LP001003LP001003LP001003LP001003LP0010...
# 2    LP001005LP001005LP001005LP001005LP001005LP0010...
# 3    LP001006LP001006LP001006LP001006LP001006LP0010...
# 4    LP001008LP001008LP001008LP001008LP001008LP0010...
# ..                                                 ...
# 609  LP002978LP002978LP002978LP002978LP002978LP0029...
# 610  LP002979LP002979LP002979LP002979LP002979LP0029...
# 611  LP002983LP002983LP002983LP002983LP002983LP0029...
# 612  LP002984LP002984LP002984LP002984LP002984LP0029...
# 613  LP002990LP002990LP002990LP002990LP002990LP0029...
#
#                                                 Gender  \
# 0             MaleMaleMaleMaleMaleMaleMaleMaleMaleMale
# 1             MaleMaleMaleMaleMaleMaleMaleMaleMaleMale
# 2             MaleMaleMaleMaleMaleMaleMaleMaleMaleMale
# 3             MaleMaleMaleMaleMaleMaleMaleMaleMaleMale
# ...
